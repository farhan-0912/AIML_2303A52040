# %% [markdown]
# <a href="https://colab.research.google.com/github/farhan-0912/AIML_2303A52040/blob/main/AIML_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 01: Lab Task is implement the following data structures using Numpy and Pandas.**
# 1.Lists
# 2.Arrays
# 3.Identify their type using type()
# 4.Perform mathematical operations on these datasets created - multiplication, division, poweroff
# 5.Combine text with Numpy fuction to generate a textual output - ”Addition of 6.6.Two: array1 +array 2
# Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
lst1=[1,2,3]
array1 = np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %% [markdown]
# Perform Mathematical Operations on these datasets - Multiplication, Division, Poweroff

# %%
import numpy as np
lst1=[1,2,3]
array1 = np.array(lst1)
list2=[3,2,1]
array2=np.array(list2) # Define array2 before it's used
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ",array2/array1)
print("array2 raised to the power of array1: ",array2**array1)
# sine function
print("Sine: ",np.sin(array1))
# logarithm
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithm: ",np.log2(array1))
# Exponential
print("Exponential: ",np.exp(array1))

print("Adding two numpy arrays {array1} and {array2} together:", array1+array2)
print(f"Adding two numpy arrays {array1} and {array2} together: {array1+array2}")
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divided by array1:  [3.         1.         0.33333333]
# array2 raised to the power of array1:  [3 4 1]
# Sine:  [0.84147098 0.90929743 0.14112001]
# Natural logarithm:  [0.         0.69314718 1.09861229]
# Base-10 logarithm:  [0.         0.30103    0.47712125]
# Base-2 logarithm:  [0.        1.        1.5849625]
# Exponential:  [ 2.71828183  7.3890561  20.08553692]
# Adding two numpy arrays {array1} and {array2} together: [4 4 4]
# Adding two numpy arrays [1 2 3] and [3 2 1] together: [4 4 4]

# %% [markdown]
# Part-02:
#
# Lab Task is to visualize the datasets or data using Matplotlib builtin function Graphs
#
# Generate Scatterplot
#
# Let's suppose we collected age (in years), height (in cm), and weight (in kilograms) information from few patients visitng a clinic.

# %%
people = ['ruthwick','farahan','aravind','David','rohith','trinay',
          'akhil','bunny','varun','kiran','rahul','harshith']
age = [21,12,32,45,37,18,28,52,5,41,44,16]
weight = [55,35,77,68,70,60,72,69,13,65,85,48]
height = [160,135,170,165,173,168,175,159,105,173,155,158]
import matplotlib.pyplot as plt
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# Generate Bar Plot

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')

# Main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='blue',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Generate Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))

# Main plot function 'hist'
plt.hist(weight,color='blue',edgecolor='k', alpha=0.60,bins=9)

plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Part-03
# Access Data from various sources and formats

# %%
import numpy as np
import pandas as pd
df1 = pd.read_table("/content/HistoricalPrices.csv")
df1
# Out:
#                         Date, Open, High, Low, Close
# 0   08/21/24, 40881.03, 40974.40, 40738.43, 40890.49
# 1   08/20/24, 40874.52, 40909.38, 40756.65, 40834.97
# 2   08/19/24, 40670.83, 40907.32, 40670.83, 40896.53
# 3   08/16/24, 40528.86, 40726.03, 40453.58, 40659.76
# 4   08/15/24, 40295.74, 40590.51, 40295.74, 40563.06
# ..                                               ...
# 56  05/31/24, 38140.26, 38719.43, 38092.27, 38686.32
# 57  05/30/24, 38368.35, 38493.60, 38000.96, 38111.48
# 58  05/29/24, 38716.28, 38716.28, 38413.67, 38441.54
# 59  05/28/24, 39028.99, 39028.99, 38706.14, 38852.86
# 60  05/24/24, 39089.23, 39220.31, 39020.29, 39069.59
#
# [61 rows x 1 columns]

# %%
data2 = pd.read_csv("/content/students.csv")
data2
# Out:
#        Name
# 0     bunny
# 1   aravind
# 2     tranz
# 3  harshith
# 4    mahesh

# %%
data3 = pd.read_excel("/content/students.xlsx")
data3
# Out:
#      Name
# 0   Akhil
# 1   rahul
# 2  rohith
# 3   rohan
# 4   bunny
